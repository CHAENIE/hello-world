# %%
import time
import pandas as pd
from selenium import webdriver as wd
from tqdm.notebook import tqdm
import re

# %%
#라인웹툰 5개국 크롤링
import time
from PIL import Image
import requests
from io import BytesIO
# request.get 요청
import pandas as pd
driver=wd.Chrome("C:/chromedriver")#,options=options)

url="https://www.webtoons.com/th/"
driver.get(url)
time.sleep(1)

names = []
images =[]
genres = []
subs = []


driver.find_element_by_css_selector('#header > div > ul > li.m03 > a').click()
time.sleep(1)


driver.find_element_by_css_selector('#content > div > div.left_area.NE\=a\:tgt > ul.lst_type1 > li.ranking_top > a > div.info_area > p.subj').click()


get_name = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h1')
get_genre = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h2')
get_sub = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[2]/div[2]/ul/li[1]/em')

names.append(get_name.text)
genres.append(get_genre.text)
subs.append(get_sub.text)


driver.back()

for i in range(2, 11):
    driver.find_element_by_css_selector('#content > div > div.left_area.NE\=a\:tgt > ul.lst_type1 > li:nth-child({0}) > a > div.info_area > p.subj'.format(i)).click()
    get_name = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h1')
    get_genre = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h2')
    get_sub = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[2]/div[2]/ul/li[1]/em')
    names.append(get_name.text)
    genres.append(get_genre.text)
    subs.append(get_sub.text)
    driver.back()
    time.sleep(1)
    
                                         
print(names)  
print(genres)
print(subs)
print(images)



df_th = pd.DataFrame({"제목(태국)" : names, "장르" : genres, '구독자' : subs})


print(df_th)
print("---------------------------------------------------------------------------------------")
names = []
images =[]
genres = []
subs = []

url="https://www.webtoons.com/en/"
driver.get(url)
time.sleep(1)


driver.find_element_by_css_selector('#header > div > ul > li.m03 > a').click()
time.sleep(1)
driver.find_element_by_css_selector('#content > div > div.left_area.NE\=a\:tgt > ul.lst_type1 > li.ranking_top > a > div.info_area > p.subj').click()

get_name = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h1')
get_genre = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h2')
get_sub = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[2]/div[2]/ul/li[1]/em')

names.append(get_name.text)
genres.append(get_genre.text)
subs.append(get_sub.text)
driver.back()

for i in range(2, 11):
    driver.find_element_by_css_selector('#content > div > div.left_area.NE\=a\:tgt > ul.lst_type1 > li:nth-child({0}) > a > div.info_area > p.subj'.format(i)).click()
    get_name = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h1')
    get_genre = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h2')
    get_sub = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[2]/div[2]/ul/li[1]/em')
    names.append(get_name.text)
    genres.append(get_genre.text)
    subs.append(get_sub.text)
    driver.back()
    time.sleep(1)
    
                                         
print(names)  
print(genres)
print(subs)

df_en = pd.DataFrame({"제목(북미)" : names, "장르" : genres, '구독자' : subs})
print(df_en)
print("---------------------------------------------------------------------------------------")

names = []
images =[]
genres = []
subs = []




url="https://www.webtoons.com/zh-hant/"
driver.get(url)
time.sleep(1)

#header > div > ul > li.m03 > a
driver.find_element_by_xpath('/html/body/div[1]/div[6]/div/div[2]/button[3]').click()
driver.find_element_by_css_selector('#header > div > ul > li.m03 > a').click()
time.sleep(1)
driver.find_element_by_css_selector('#content > div > div.left_area.NE\=a\:tgt > ul.lst_type1 > li.ranking_top > a > div.info_area > p.subj').click()

get_name = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h1')
get_genre = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h2')
get_sub = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[2]/div[2]/ul/li[1]/em')

names.append(get_name.text)
genres.append(get_genre.text)
subs.append(get_sub.text)


driver.back()

for i in range(2, 11):
    driver.find_element_by_css_selector('#content > div > div.left_area.NE\=a\:tgt > ul.lst_type1 > li:nth-child({0}) > a > div.info_area > p.subj'.format(i)).click()
    get_name = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h1')
    get_genre = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h2')
    get_sub = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[2]/div[2]/ul/li[1]/em')
    names.append(get_name.text)
    genres.append(get_genre.text)
    subs.append(get_sub.text)
    driver.back()
    time.sleep(1)
    
                                         
print(names)  
print(genres)
print(subs)


df_zh_hant = pd.DataFrame({"제목(중국)" : names, "장르" : genres, '구독자' : subs})

print(df_zh_hant)
print("---------------------------------------------------------------------------------------")

names = []
images =[]
genres = []
subs = []




url="https://www.webtoons.com/id/"
driver.get(url)
time.sleep(1)


driver.find_element_by_css_selector('#header > div > ul > li.m03 > a').click()
time.sleep(1)
driver.find_element_by_css_selector('#content > div > div.left_area.NE\=a\:tgt > ul.lst_type1 > li.ranking_top > a > div.info_area > p.subj').click()


get_name = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h1')
get_genre = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h2')
get_sub = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[2]/div[2]/ul/li[1]/em')

names.append(get_name.text)
genres.append(get_genre.text)
subs.append(get_sub.text)

driver.back()

for i in range(2, 11):
    driver.find_element_by_css_selector('#content > div > div.left_area.NE\=a\:tgt > ul.lst_type1 > li:nth-child({0}) > a > div.info_area > p.subj'.format(i)).click()
    get_name = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h1')
    get_genre = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h2')
    get_sub = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[2]/div[2]/ul/li[1]/em')
    names.append(get_name.text)
    genres.append(get_genre.text)
    subs.append(get_sub.text)
    driver.back()
    time.sleep(1)
    
                                         
print(names)  
print(genres)
print(subs)


df_id = pd.DataFrame({"제목(인도네시아)" : names, "장르" : genres, '구독자' : subs})

print(df_id)
print("---------------------------------------------------------------------------------------")

names = []
images =[]
genres = []
subs = []







url="https://www.webtoons.com/es/"
driver.get(url)
time.sleep(1)


driver.find_element_by_css_selector('#header > div > ul > li.m03 > a').click()
time.sleep(1)
driver.find_element_by_css_selector('#content > div > div.left_area.NE\=a\:tgt > ul.lst_type1 > li.ranking_top > a > div.info_area > p.subj').click()


get_name = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h1')
get_genre = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h2')
get_sub = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[2]/div[2]/ul/li[1]/em')

names.append(get_name.text)
genres.append(get_genre.text)
subs.append(get_sub.text)


driver.back()

for i in range(2, 11):
    driver.find_element_by_css_selector('#content > div > div.left_area.NE\=a\:tgt > ul.lst_type1 > li:nth-child({0}) > a > div.info_area > p.subj'.format(i)).click()
    get_name = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h1')
    get_genre = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h2')
    get_sub = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[2]/div[2]/ul/li[1]/em')
    names.append(get_name.text)
    genres.append(get_genre.text)
    subs.append(get_sub.text)
    driver.back()
    time.sleep(1)
    
                                         
print(names)  
print(genres)
print(subs)


df_es = pd.DataFrame({"제목(스페인)" : names, "장르" : genres, '구독자' : subs})

print(df_es)
print("---------------------------------------------------------------------------------------")

names = []
images =[]
genres = []
subs = []







url="https://www.webtoons.com/fr/"
driver.get(url)
time.sleep(1)


driver.find_element_by_css_selector('#header > div > ul > li.m03 > a').click()
time.sleep(1)
driver.find_element_by_css_selector('#content > div > div.left_area.NE\=a\:tgt > ul.lst_type1 > li.ranking_top > a > div.info_area > p.subj').click()


get_name = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h1')
get_genre = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h2')
get_sub = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[2]/div[2]/ul/li[1]/em')

names.append(get_name.text)
genres.append(get_genre.text)
subs.append(get_sub.text)

driver.back()

for i in range(2, 11):
    driver.find_element_by_css_selector('#content > div > div.left_area.NE\=a\:tgt > ul.lst_type1 > li:nth-child({0}) > a > div.info_area > p.subj'.format(i)).click()
    get_name = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h1')
    get_genre = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h2')
    get_sub = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[2]/div[2]/ul/li[1]/em')
    names.append(get_name.text)
    genres.append(get_genre.text)
    subs.append(get_sub.text)
    driver.back()
    time.sleep(1)
    
                                         
print(names)  
print(genres)
print(subs)


df_fr = pd.DataFrame({"제목(프랑스)" : names, "장르" : genres, '구독자' : subs})

print(df_fr)
print("---------------------------------------------------------------------------------------")
# Out:
# ['ความลับของนางฟ้า', 'การแต่งงานครั้งใหม่ของจักรพรรดินี', 'อยู่ๆ ฉันก็กลายเป็นเจ้าหญิง', 'The Boxer', 'Summer Night ความลับในคืนฤดูร้อน', 'ชาตินี้ก็ฝากด้วยนะ', 'นักสู้ทูปเบอร์', 'เจ้าหญิงผมดำกับเจ้าชายผมแดง', 'Take My Money รักนี้...มีเปย์', 'ฟา องครักษ์หญิงจำเป็น']
# ['โรแมนซ์', 'ดราม่า', 'แฟนตาซี', 'แอ็คชั่น', 'โรแมนซ์', 'โรแมนซ์', 'แอ็คชั่น', 'โรแมนซ์', 'โรแมนซ์', 'แฟนตาซี']
# ['2M', '498.9K', '777.5K', '232.2K', '588K', '135.1K', '215K', '155.3K', '457.7K', '777.1K']
# []
#                               제목(태국)        장르     구독자
# 0                   ความลับของนางฟ้า   โรแมนซ์      2M
# 1  การแต่งงานครั้งใหม่ของจักรพรรดินี    ดราม่า  498.9K
# 2        อยู่ๆ ฉันก็กลายเป็นเจ้าหญิง   แฟนตาซี  777.5K
# 3                          The Boxer  แอ็คชั่น  232.2K
# 4   Summer Night ความลับในคืนฤดูร้อน   โรแมนซ์    588K
# 5                 ชาตินี้ก็ฝากด้วยนะ   โรแมนซ์  135.1K
# 6                     นักสู้ทูปเบอร์  แอ็คชั่น    215K
# 7        เจ้าหญิงผมดำกับเจ้าชายผมแดง   โรแมนซ์  155.3K
# 8      Take My Money รักนี้...มีเปย์   โรแมนซ์  457.7K
# 9              ฟา องครักษ์หญิงจำเป็น   แฟนตาซี  777.1K
# ---------------------------------------------------------------------------------------
# ["Let's Play", 'Lore Olympus', 'True Beauty', 'Midnight Poppy Land', 'SubZero', 'unOrdinary', 'Freaking Romance', 'Cursed Princess Club', 'Down To Earth', 'Age Matters']
# ['Romance', 'Romance', 'Romance', 'Romance', 'Romance', 'Superhero', 'Romance', 'Comedy', 'Romance', 'Romance']
# ['3.5M', '4M', '4.6M', '1.4M', '2M', '4.3M', '2M', '1.4M', '806.8K', '2.5M']
#                  제목(북미)         장르     구독자
# 0            Let's Play    Romance    3.5M
# 1          Lore Olympus    Romance      4M
# 2           True Beauty    Romance    4.6M
# 3   Midnight Poppy Land    Romance    1.4M
# 4               SubZero    Romance      2M
# 5            unOrdinary  Superhero    4.3M
# 6      Freaking Romance    Romance      2M
# 7  Cursed Princess Club     Comedy    1.4M
# 8         Down To Earth    Romance  806.8K
# 9           Age Matters    Romance    2.5M
# ---------------------------------------------------------------------------------------
# ['女神降臨', '我與教授難以啟齒', '再婚皇后', '我奪走了公爵的初夜', '乖乖女的戀愛指南', '惡女的變身', '1加1', '愛上冤家', '盜臉人生', '看臉時代']
# ['劇情', '愛情', '劇情', '劇情', '愛情', '劇情', '愛情', '愛情', '劇情', '劇情']
# ['97.9萬', '32萬', '26.7萬', '4.9萬', '28.9萬', '17.5萬', '19.9萬', '25萬', '24萬', '98.3萬']
#       제목(중국)  장르    구독자
# 0       女神降臨  劇情  97.9萬
# 1   我與教授難以啟齒  愛情    32萬
# 2       再婚皇后  劇情  26.7萬
# 3  我奪走了公爵的初夜  劇情   4.9萬
# 4   乖乖女的戀愛指南  愛情  28.9萬
# 5      惡女的變身  劇情  17.5萬
# 6        1加1  愛情  19.9萬
# 7       愛上冤家  愛情    25萬
# 8       盜臉人生  劇情    24萬
# 9       看臉時代  劇情  98.3萬
# ---------------------------------------------------------------------------------------
# ['The Secret of Angel', 'Mistake', 'My Anti-Fan!', 'A Royal Princess with Black Hair', 'iMarried', 'The Second Marriage', 'Killstagram', 'Wendy the Florist', 'Eggnoid', 'Suddenly, I Became a Princess']
# ['drama', 'drama', 'romantis', 'romantis', 'romantis', 'romantis', 'horor', 'romantis', 'romantis', 'fantasi']
# ['4.7M', '1.3M', '1.2M', '244.9K', '2.1M', '593K', '1M', '935.2K', '4.5M', '934.1K']
#                           제목(인도네시아)        장르     구독자
# 0               The Secret of Angel     drama    4.7M
# 1                           Mistake     drama    1.3M
# 2                      My Anti-Fan!  romantis    1.2M
# 3  A Royal Princess with Black Hair  romantis  244.9K
# 4                          iMarried  romantis    2.1M
# 5               The Second Marriage  romantis    593K
# 6                       Killstagram     horor      1M
# 7                 Wendy the Florist  romantis  935.2K
# 8                           Eggnoid  romantis    4.5M
# 9     Suddenly, I Became a Princess   fantasi  934.1K
# ---------------------------------------------------------------------------------------
# ['Secretos de belleza', 'Maldito romance', 'Cuestión de edad', 'Mi secreto más íntimo', 'Cuentos del Olimpo', "Let's Play", 'Apuesta de amor', 'Yo soy la muerte', 'extraOrdinario', 'Poppy a la medianoche']
# ['Drama', 'Romance', 'Romance', 'Drama', 'Romance', 'Romance', 'Romance', 'Suspenso', 'Acción', 'Romance']
# ['1M', '612.8K', '763K', '693.2K', '783.5K', '474.8K', '247.8K', '291.2K', '367.2K', '107.7K']
#                  제목(스페인)        장르     구독자
# 0    Secretos de belleza     Drama      1M
# 1        Maldito romance   Romance  612.8K
# 2       Cuestión de edad   Romance    763K
# 3  Mi secreto más íntimo     Drama  693.2K
# 4     Cuentos del Olimpo   Romance  783.5K
# 5             Let's Play   Romance  474.8K
# 6        Apuesta de amor   Romance  247.8K
# 7       Yo soy la muerte  Suspenso  291.2K
# 8         extraOrdinario    Acción  367.2K
# 9  Poppy a la medianoche   Romance  107.7K
# ---------------------------------------------------------------------------------------
# ['True Beauty', 'SubZero', "Traditions d'Olympus", 'Foutue Romance', "Let's Play", 'I Love Yoo', "Questions d'âge", 'My Lovely Bodyguard', 'Diable n°4', 'LUMINE']
# ['Drama', 'Romance', 'Romance', 'Romance', 'Romance', 'Romance', 'Romance', 'Romance', 'Romance', 'Fantastique']
# ['314.4K', '227.8K', '259.7K', '186.7K', '296K', '196K', '190.8K', '137.1K', '166.5K', '108.7K']
#                 제목(프랑스)           장르     구독자
# 0           True Beauty        Drama  314.4K
# 1               SubZero      Romance  227.8K
# 2  Traditions d'Olympus      Romance  259.7K
# 3        Foutue Romance      Romance  186.7K
# 4            Let's Play      Romance    296K
# 5            I Love Yoo      Romance    196K
# 6       Questions d'âge      Romance  190.8K
# 7   My Lovely Bodyguard      Romance  137.1K
# 8            Diable n°4      Romance  166.5K
# 9                LUMINE  Fantastique  108.7K
# ---------------------------------------------------------------------------------------

# %%
df_fr
# Out:
#                 제목(프랑스)           장르     구독자
# 0           True Beauty        Drama  314.4K
# 1               SubZero      Romance  227.8K
# 2  Traditions d'Olympus      Romance  259.7K
# 3        Foutue Romance      Romance  186.7K
# 4            Let's Play      Romance    296K
# 5            I Love Yoo      Romance    196K
# 6       Questions d'âge      Romance  190.8K
# 7   My Lovely Bodyguard      Romance  137.1K
# 8            Diable n°4      Romance  166.5K
# 9                LUMINE  Fantastique  108.7K

# %%
df_zh_hant
# Out:
#       제목(중국)  장르    구독자
# 0       女神降臨  劇情  97.9萬
# 1   我與教授難以啟齒  愛情    32萬
# 2       再婚皇后  劇情  26.7萬
# 3  我奪走了公爵的初夜  劇情   4.9萬
# 4   乖乖女的戀愛指南  愛情  28.9萬
# 5      惡女的變身  劇情  17.5萬
# 6        1加1  愛情  19.9萬
# 7       愛上冤家  愛情    25萬
# 8       盜臉人生  劇情    24萬
# 9       看臉時代  劇情  98.3萬

# %%
df_en
# Out:
#                  제목(북미)         장르     구독자
# 0            Let's Play    Romance    3.5M
# 1          Lore Olympus    Romance      4M
# 2           True Beauty    Romance    4.6M
# 3   Midnight Poppy Land    Romance    1.4M
# 4               SubZero    Romance      2M
# 5            unOrdinary  Superhero    4.3M
# 6      Freaking Romance    Romance      2M
# 7  Cursed Princess Club     Comedy    1.4M
# 8         Down To Earth    Romance  806.8K
# 9           Age Matters    Romance    2.5M

# %%
df_es
# Out:
#                  제목(스페인)        장르     구독자
# 0    Secretos de belleza     Drama      1M
# 1        Maldito romance   Romance  612.8K
# 2       Cuestión de edad   Romance    763K
# 3  Mi secreto más íntimo     Drama  693.2K
# 4     Cuentos del Olimpo   Romance  783.5K
# 5             Let's Play   Romance  474.8K
# 6        Apuesta de amor   Romance  247.8K
# 7       Yo soy la muerte  Suspenso  291.2K
# 8         extraOrdinario    Acción  367.2K
# 9  Poppy a la medianoche   Romance  107.7K

# %%
df_fr
# Out:
#                 제목(프랑스)           장르     구독자
# 0           True Beauty        Drama  314.4K
# 1               SubZero      Romance  227.8K
# 2  Traditions d'Olympus      Romance  259.7K
# 3        Foutue Romance      Romance  186.7K
# 4            Let's Play      Romance    296K
# 5            I Love Yoo      Romance    196K
# 6       Questions d'âge      Romance  190.8K
# 7   My Lovely Bodyguard      Romance  137.1K
# 8            Diable n°4      Romance  166.5K
# 9                LUMINE  Fantastique  108.7K

# %%
df_id
# Out:
#                           제목(인도네시아)        장르     구독자
# 0               The Secret of Angel     drama    4.7M
# 1                           Mistake     drama    1.3M
# 2                      My Anti-Fan!  romantis    1.2M
# 3  A Royal Princess with Black Hair  romantis  244.9K
# 4                          iMarried  romantis    2.1M
# 5               The Second Marriage  romantis    593K
# 6                       Killstagram     horor      1M
# 7                 Wendy the Florist  romantis  935.2K
# 8                           Eggnoid  romantis    4.5M
# 9     Suddenly, I Became a Princess   fantasi  934.1K

# %%
df_th
# Out:
#                               제목(태국)        장르     구독자
# 0                   ความลับของนางฟ้า   โรแมนซ์      2M
# 1  การแต่งงานครั้งใหม่ของจักรพรรดินี    ดราม่า  498.9K
# 2        อยู่ๆ ฉันก็กลายเป็นเจ้าหญิง   แฟนตาซี  777.5K
# 3                          The Boxer  แอ็คชั่น  232.2K
# 4   Summer Night ความลับในคืนฤดูร้อน   โรแมนซ์    588K
# 5                 ชาตินี้ก็ฝากด้วยนะ   โรแมนซ์  135.1K
# 6                     นักสู้ทูปเบอร์  แอ็คชั่น    215K
# 7        เจ้าหญิงผมดำกับเจ้าชายผมแดง   โรแมนซ์  155.3K
# 8      Take My Money รักนี้...มีเปย์   โรแมนซ์  457.7K
# 9              ฟา องครักษ์หญิงจำเป็น   แฟนตาซี  777.1K

# %%
#라인 웹툰 작품 수(연재/완결)
import time
from PIL import Image
import requests
from io import BytesIO
from selenium import webdriver as wd
# request.get 요청
import pandas as pd
driver=wd.Chrome("C:/chromedriver")#,options=options)

print("북미--------------------------------")


url="https://www.webtoons.com/en/"
driver.get(url)
time.sleep(1)


driver.find_element_by_css_selector('#weekdayList > div.daily_tab_wrap > div > a').click()
time.sleep(1)


#mon = driver.find_elements_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/ul/li')
#print(len(mon))

en_count_list=[]
for c in range(1,8):
    en_count=driver.find_elements_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[{0}]/ul/li'.format(c))
    print(len(en_count))
    en_count_list.append(len(en_count))

en_count_list1=len(driver.find_elements_by_xpath('//*[@id="content"]/div[3]/div/ul/li'))

    
sum_en_count=sum(en_count_list)
hap_en = [sum_en_count,en_count_list1]
print(type(hap_en))
print(sum_en_count)

print("북미 완결 작품 수:",en_count_list1)


print("태국--------------------------------")

url="https://www.webtoons.com/th/"
driver.get(url)
time.sleep(1)


driver.find_element_by_css_selector('#weekdayList > div.daily_tab_wrap > div > a').click()
time.sleep(1)


#mon = driver.find_elements_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/ul/li')
#print(len(mon))

th_count_list=[]
for c in range(1,8):
    th_count=driver.find_elements_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[{0}]/ul/li'.format(c))
    print(len(th_count))
    th_count_list.append(len(th_count))

th_count_list1=len(driver.find_elements_by_xpath('//*[@id="content"]/div[3]/div/ul/li'))

sum_th_count=sum(th_count_list)
hap_th = [sum_th_count,th_count_list1]
print(sum_th_count)    
print(type(hap_th))


print("태국 완결 작품 수:",th_count_list1)    
print("인도네시아--------------------------------")

url="https://www.webtoons.com/id/"
driver.get(url)
time.sleep(1)


driver.find_element_by_css_selector('#weekdayList > div.daily_tab_wrap > div > a').click()
time.sleep(1)


#mon = driver.find_elements_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/ul/li')
#print(len(mon))

id_count_list=[]
for c in range(1,8):
    id_count=driver.find_elements_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[{0}]/ul/li'.format(c))
    print(len(id_count))
    id_count_list.append(len(id_count))   

id_count_list1=len(driver.find_elements_by_xpath('//*[@id="content"]/div[3]/div/ul/li'))
    
sum_id_count=sum(id_count_list)
hap_id = [sum_id_count,id_count_list1]
print(type(hap_id))
print(sum_id_count)    
    

print("인도네시아 완결 작품 수:",id_count_list1)        
print("스페인--------------------------------")

url="https://www.webtoons.com/es/"
driver.get(url)
time.sleep(1)


driver.find_element_by_css_selector('#weekdayList > div.daily_tab_wrap > div > a').click()
time.sleep(1)


#mon = driver.find_elements_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/ul/li')
#print(len(mon))

es_count_list=[]
for c in range(1,8):
    es_count=driver.find_elements_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[{0}]/ul/li'.format(c))
    print(len(es_count))
    es_count_list.append(len(es_count))   
es_count_list1=len(driver.find_elements_by_xpath('//*[@id="content"]/div[3]/div/ul/li'))

sum_es_count=sum(es_count_list)
hap_es = [sum_es_count,es_count_list1]
print(type(hap_es))
print(sum_es_count) 

print("스페인 완결 작품 수:",es_count_list1)        
print("프랑스--------------------------------")

url="https://www.webtoons.com/fr/"
driver.get(url)
time.sleep(1)


driver.find_element_by_css_selector('#weekdayList > div.daily_tab_wrap > div > a').click()
time.sleep(1)


#mon = driver.find_elements_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/ul/li')
#print(len(mon))

fr_count_list=[]
for c in range(1,8):
    fr_count=driver.find_elements_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[{0}]/ul/li'.format(c))
    print(len(fr_count))
    fr_count_list.append(len(fr_count))

fr_count_list1=len(driver.find_elements_by_xpath('//*[@id="content"]/div[3]/div/ul/li'))

sum_fr_count=sum(fr_count_list)
hap_fr = [sum_fr_count,fr_count_list1]
print(type(hap_fr))
print(sum_fr_count) 

print("프랑스 완결 작품 수:",fr_count_list1)    
print("중국--------------------------------")

url="https://www.webtoons.com/"
driver.get(url)
time.sleep(1)


driver.find_element_by_xpath('/html/body/div[1]/div[4]/ul/li[9]/a').click()
time.sleep(1)
driver.find_element_by_xpath('/html/body/div[1]/div[4]/ul/li[9]/ul/li[2]/a').click()
time.sleep(1)
driver.find_element_by_xpath('/html/body/div[1]/div[6]/div/div[2]/button[3]').click()
time.sleep(1)

driver.find_element_by_css_selector('#weekdayList > div.daily_tab_wrap > div > a').click()
time.sleep(1)

#mon = driver.find_elements_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/ul/li')
#print(len(mon))

zh_count_list=[]
for c in range(1,8):
    zh_count=driver.find_elements_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[{0}]/ul/li'.format(c))
    print(len(zh_count))
    zh_count_list.append(len(zh_count))
zh_count_list1=len(driver.find_elements_by_xpath('//*[@id="content"]/div[3]/div/ul/li'))

sum_zh_count=sum(zh_count_list)
hap_zh = [sum_zh_count,zh_count_list1]
print(type(hap_zh))
print(sum_zh_count) 


print("중국 완결 작품 수:",zh_count_list1)
# Out:
# 북미--------------------------------
# 29
# 32
# 33
# 28
# 32
# 33
# 24
# <class 'list'>
# 211
# 북미 완결 작품 수: 193
# 태국--------------------------------
# 22
# 19
# 18
# 18
# 18
# 20
# 21
# 136
# <class 'list'>
# 태국 완결 작품 수: 158
# 인도네시아--------------------------------
# 25
# 20
# 19
# 27
# 22
# 25
# 25
# <class 'list'>
# 163
# 인도네시아 완결 작품 수: 169
# 스페인--------------------------------
# 15
# 12
# 11
# 14
# 13
# 14
# 15
# <class 'list'>
# 94
# 스페인 완결 작품 수: 4
# 프랑스--------------------------------
# 19
# 20
# 21
# 24
# 22
# 20
# 19
# <class 'list'>
# 145
# 프랑스 완결 작품 수: 2
# 중국--------------------------------
# 26
# 24
# 26
# 24
# 25
# 32
# 27
# <class 'list'>
# 184
# 중국 완결 작품 수: 303

# %%
df_en_count1
# Out:
#    완결 작품 합계(북미)  연재 작품 합계(북미)
# 0           193            29
# 1           193            32
# 2           193            33
# 3           193            28
# 4           193            32
# 5           193            33
# 6           193            24

# %% [markdown]
# <img src="aa.PNG"/>

# %%
#연도별 한국 네이버 웹툰 작품 수
import time
from PIL import Image
import requests
from io import BytesIO
from selenium import webdriver as wd
# request.get 요청
import pandas as pd
import re
driver=wd.Chrome("C:/chromedriver")#,options=options)

url="https://comic.naver.com/webtoon/period.nhn?period=2018"
driver.get(url)
time.sleep(1)
cnts = []
yearss= []
# years = driver.find_elements_by_xpath('/html/body/div/div[3]/div[1]/ul/li')
years = driver.find_elements_by_xpath('/html/body/div/div[3]/div[1]/ul/li')
years = len(years)
for i in range(years):
    
    driver.find_element_by_css_selector('#content > ul > li:nth-child({0}) > a'.format(i+1)).click()
    get_year = driver.find_element_by_css_selector('#content > ul > li:nth-child({0}) > a'.format(i+1))
    cnt = driver.find_element_by_xpath('/html/body/div/div[3]/div[1]/div[1]/h3/span')
    cnts.append(cnt.text)
    yearss.append(get_year.text)


piece = list(map(lambda x: int(re.findall('\d+', x)[0]), cnts))
years = list(map(int, yearss))
df = pd.DataFrame({'년도':years, '작품수' : piece})
df
# Out:
#       년도  작품수
# 0   2020  445
# 1   2019  414
# 2   2018  288
# 3   2017  222
# 4   2016  216
# 5   2015  229
# 6   2014  204
# 7   2013  185
# 8   2012  169
# 9   2011  148
# 10  2010  113
# 11  2009   82
# 12  2008   56
# 13  2007   26
# 14  2006   10
# 15  2005    3

# %%
#라인 웹툰 작품 수(연재/완결)
import time
from PIL import Image
import requests
from io import BytesIO
from selenium import webdriver as wd
# request.get 요청
import pandas as pd
driver=wd.Chrome("C:/chromedriver")#,options=options)

print("북미--------------------------------")


url="https://www.webtoons.com/en/"
driver.get(url)
time.sleep(1)


driver.find_element_by_css_selector('#weekdayList > div.daily_tab_wrap > div > a').click()
time.sleep(1)


#mon = driver.find_elements_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/ul/li')
#print(len(mon))

en_count_list=[]
for c in range(1,8):
    en_count=driver.find_elements_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[{0}]/ul/li'.format(c))
    print(len(en_count))
    en_count_list.append(len(en_count))
# df_en_count = pd.DataFrame({"연재 작품 합계(북미)" : en_count_list})    

en_count_list1=len(driver.find_elements_by_xpath('//*[@id="content"]/div[3]/div/ul/li'))
print("북미 완결 작품 수:",en_count_list1)
# df_en_count1 = pd.DataFrame({"완결 작품 합계(북미)" : en_count_list1})
sum_en_count=sum(en_count_list)
hap_en = [sum_en_count,en_count_list1]
print(type(hap_en))
# Out:
# 북미--------------------------------
# 29
# 32
# 33
# 28
# 32
# 33
# 24
# 북미 완결 작품 수: 193
# <class 'list'>

# %%
type(sum_en_count)
# Out:
# int

# %%
type(en_count_list1)
# Out:
# int

# %%
df_count = pd.DataFrame({"영어" : [sum_en_count,en_count_list1, sum(hap_en)],
                         "중국어(간체)":[sum_zh_count,zh_count_list1, sum(hap_zh)],
                         "태국어":[sum_th_count,th_count_list1, sum(hap_th)],
                         "인도네시아어": [sum_id_count,id_count_list1, sum(hap_id)],
                         "스페인어": [sum_es_count,es_count_list1, sum(hap_es)],
                         "프랑스어": [sum_fr_count,fr_count_list1, sum(hap_fr)]},
                        index=['연재중 작품 수','완결 작품 수','총 작품 수' ])

# %%
df_count
# Out:
#            영어  중국어(간체)  태국어  인도네시아어  스페인어  프랑스어
# 연재중 작품 수  211      184  136     163    94   145
# 완결 작품 수   193      303  158     169     4     2
# 총 작품 수    404      487  294     332    98   147

# %%
import numpy as np 
import matplotlib.pyplot as plt

s1 = [556,559,605,671,692,683,674,663,651,640]
s2 = [478,499,489,485,481,469,457,443,429,413]
s3 = [495,536,540,536,530,519,508,495,481,466]

N = len(s1)
ind = np.arange(N) 
width = 0.23

p1 = plt.bar(ind-0.25, s1, width) 
p2 = plt.bar(ind, s2, width) 
p3 = plt.bar(ind+0.25, s3, width) 

plt.ylabel('Scores') 
plt.rcParams["font.family"] = "Malgun Gothic"
plt.title('인쇄 만화 시장 규모') 
plt.xticks(ind, ('2010','2011','2012','2013','2014','2015','2016','2017','2018','2019')) 
plt.rcParams["font.family"] = "Malgun Gothic"
plt.legend((p1[0], p2[0],p3[0]), ('미국', '프랑스','독일'))
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt

s1 = [47,65,99,146,186,210,234,259,284,308]
s2 = [13,20,26,33,40,45,50,55,60,65]
s3 = [11,16,21,27,32,36,40,45,49,54]

N = len(s1)
ind = np.arange(N) 
width = 0.23

p1 = plt.bar(ind-0.25, s1, width) 
p2 = plt.bar(ind, s2, width) 
p3 = plt.bar(ind+0.25, s3, width) 

plt.ylabel('Scores') 
plt.rcParams["font.family"] = "Malgun Gothic"
plt.title('미디어 만화 시장 규모') 
plt.xticks(ind, ('2010','2011','2012','2013','2014','2015','2016','2017','2018','2019')) 
plt.rcParams["font.family"] = "Malgun Gothic"
plt.legend((p1[0], p2[0],p3[0]), ('미국', '프랑스','독일'))
plt.show()

# %%
#라인 웹툰 태국 TOP10 크롤링
import time
from PIL import Image
import requests
from io import BytesIO
# request.get 요청
import pandas as pd
driver=wd.Chrome("C:/chromedriver")#,options=options)

url="https://www.webtoons.com/th/"
driver.get(url)
time.sleep(1)

names = []
images =[]
genres = []
subs = []


driver.find_element_by_css_selector('#header > div > ul > li.m03 > a').click()
time.sleep(1)


driver.find_element_by_css_selector('#content > div > div.left_area.NE\=a\:tgt > ul.lst_type1 > li.ranking_top > a > div.info_area > p.subj').click()


get_name = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h1')
get_genre = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h2')
get_sub = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[2]/div[2]/ul/li[1]/em')

names.append(get_name.text)
genres.append(get_genre.text)
subs.append(get_sub.text)


driver.back()

for i in range(2, 11):
    driver.find_element_by_css_selector('#content > div > div.left_area.NE\=a\:tgt > ul.lst_type1 > li:nth-child({0}) > a > div.info_area > p.subj'.format(i)).click()
    get_name = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h1')
    get_genre = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h2')
    get_sub = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[2]/div[2]/ul/li[1]/em')
    names.append(get_name.text)
    genres.append(get_genre.text)
    subs.append(get_sub.text)
    driver.back()
    time.sleep(1)
    
                                         
print(names)  
print(genres)
print(subs)
print(images)



df_th = pd.DataFrame({"제목(태국)" : names, "장르" : genres, '구독자' : subs})


print(df_th)
print("---------------------------------------------------------------------------------------")
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-247-c619e3607b78> in <module>
#      38 for i in range(2, 11):
#      39     driver.find_element_by_css_selector('#content > div > div.left_area.NE\=a\:tgt > ul.lst_type1 > li:nth-child({0}) > a > div.info_area > p.subj'.format(i)).click()
# ---> 40     get_name = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h1')
#      41     get_genre = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[1]/div[1]/h2')
#      42     get_sub = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[2]/div[2]/div[2]/ul/li[1]/em')
#
# c:\deep\datab\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# c:\deep\datab\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# c:\deep\datab\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# c:\deep\datab\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=84.0.4147.105)
