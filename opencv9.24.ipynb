# %% [markdown]
# # openCV

# %%
import os

cd=os.getcwd()
print(cd)
# Out:
# C:\Users\user

# %%
import sys
import cv2

print('Hello OpenCV', cv2.__version__)

img=cv2.imread('C:\deep\opencv\image\cup.jpg')

if img is None:
    print('Image load failed!')
    sys.exit()
    
cv2.namedWindow('image')
cv2.imshow('image',img)
key=cv2.waitKey()
print(key)

cv2.destroyAllWindows()
# Out:
# Hello OpenCV 3.4.2

# %%
import sys
import cv2

img=cv2.imread('C:\deep\opencv\image\cup.jpg',cv2.IMREAD_GRAYSCALE)

if img is None:
    print('image load failed!')
    sys.exit()
    
cv2.imwrite('cup_gray.jpg', img)

cv2.namedWindow('image')

cv2.imshow('image', img)

while True:
    if cv2.waitKey()==13:
        break
        
cv2.destroyAllWindows()

# %%
import sys
import cv2

img=cv2.imread('C:\deep\opencv\image\cup.jpg',cv2.IMREAD_GRAYSCALE)

if img is None:
    print('image load failed!')
    sys.exit()
    
cv2.imwrite('cup_gray.jpg', img)

cv2.namedWindow('image')
cv2.imshow('image', img)

while True:
    if cv2.waitKey()==ord('x'):
        break
        
cv2.destroyAllWindows()

# %% [markdown]
# # matplotlib 연동

# %%
import matplotlib.pyplot as plt
import cv2

imgBGR=cv2.imread('C:\deep\opencv\image\cup.jpg')
imgRGB=cv2.cvtColor(imgBGR, cv2.COLOR_BGR2RGB)

plt.axis('off')

plt.imshow(imgRGB)
plt.show()

imgGray=cv2.imread('C:\deep\opencv\image\cup.jpg', cv2.IMREAD_GRAYSCALE)
plt.axis('off')

plt.imshow(imgGray, cmap='gray')
plt.show()

# %%
import matplotlib.pyplot as plt
import cv2

imgBGR=cv2.imread('C:\deep\opencv\image\cup.jpg')
imgRGB=cv2.cvtColor(imgBGR, cv2.COLOR_BGR2RGB)
imgGray=cv2.imread('C:\deep\opencv\image\cup.jpg', cv2.IMREAD_GRAYSCALE)

plt.subplot(121), plt.axis('off'), plt.imshow(imgRGB)
plt.subplot(122), plt.axis('off'), plt.imshow(imgGray, cmap='gray')

plt.show()

# %% [markdown]
# # 슬라이드쇼

# %%
import glob
import sys
import cv2

img_files=glob.glob('C:\\deep\\opencv\\image\\*.jpg')

for f in img_files:
    print(f)
# Out:
# C:\deep\opencv\image\autumn_forest_park_128379_1920x1080.jpg
# C:\deep\opencv\image\boat_mountains_lake_135258_1920x1080.jpg
# C:\deep\opencv\image\cup.jpg
# C:\deep\opencv\image\forest_fog_trees_128751_1920x1080.jpg
# C:\deep\opencv\image\hongkong.jpg
# C:\deep\opencv\image\pier_dock_sea_dusk_shore_118549_1920x1080.jpg
# C:\deep\opencv\image\road_marking_evening_clouds_horizon_120298_1920x1080.jpg

# %%
import glob
import sys
import cv2

img_files=glob.glob('.\\image\\*.jpg')

for f in img_files:
    print(f)
# Out:
# .\image\autumn_forest_park_128379_1920x1080.jpg
# .\image\boat_mountains_lake_135258_1920x1080.jpg
# .\image\cup.jpg
# .\image\forest_fog_trees_128751_1920x1080.jpg
# .\image\hongkong.jpg
# .\image\pier_dock_sea_dusk_shore_118549_1920x1080.jpg
# .\image\road_marking_evening_clouds_horizon_120298_1920x1080.jpg

# %%
import glob
import os
import sys
import cv2

img_files=glob.glob('C:\\deep\\opencv\\image\\*.jpg')

if not img_files:
    print("There are no jpg files in 'images' folder")
    sys.exit()
    
cv2.namedWindow('image', cv2.WINDOW_NORMAL)
cv2.setWindowProperty('image', cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

cnt=len(img_files)
idx=0

while True:
    img=cv2.imread(img_files[idx])
    if img is None:
        print('image load failed')
        break
    cv2.imshow('image',img)
    if cv2.waitKey(2000)>=0:
        break
        
    idx +=1
    if idx>=cnt:
        idx=0

cv2.destroyAllWindows()

# %% [markdown]
# # openCV 주요기능( 4장 )

# %% [markdown]
# 영상 속성 픽셀

# %%
import sys
import cv2

img1=cv2.imread('C:\deep\opencv\image\cup.jpg', cv2.IMREAD_GRAYSCALE)
img2=cv2.imread('C:\deep\opencv\image\cup.jpg', cv2.IMREAD_COLOR)

if img1 is None or img2 is None:
    print('image load failed')
    sys.exit()
    
print('type(img1):',type(img1))
print('type(img2):',type(img2))
print('img1.shape:',img1.shape)
print('img2.shape:',img2.shape)
print('img1.dtype:',img1.dtype)
print('img2.dtype:',img2.dtype)

if img1.ndim==2:
    print('img1 is color')
# Out:
# type(img1): <class 'numpy.ndarray'>
# type(img2): <class 'numpy.ndarray'>
# img1.shape: (426, 500)
# img2.shape: (426, 500, 3)
# img1.dtype: uint8
# img2.dtype: uint8
# img1 is color

# %%
x=100
y=50

img1[y,x]=0
img2[y,x]=(0,255,255)
#img1[:,:]=0
#img2[:,:]=(0,255,255)

cv2.imshow('img1',img1)
cv2.imshow('img2', img2)

while True:
    if cv2.waitKey()==27:
        break
cv2.destroyAllWindows()

# %%
h,w=img1.shape[:2]
print('img1.size {} x {}'.format(w,h))
h,w=img2.shape[:2]
print('img2.size {} x {}'.format(w,h))

if len(img1.shape)==2:
    print('img1 is a grayscale image')
elif len(img1.shape)==3:
    print('img1 is a truecolor image')

if len(img2.shape)==2:
    print('img2 is a grayscale image')
elif len(img2.shape)==3:
    print('img2 is a truecolor image')
# Out:
# img1.size 500 x 426
# img2.size 500 x 426
# img1 is a grayscale image
# img2 is a truecolor image

# %% [markdown]
# # 영상 생성

# %%
import numpy as np
import cv2

img1=np.empty((240,320), dtype=np.uint8)
img2=np.zeros((240,320,3), dtype=np.uint8)
img3=np.ones((240,320), dtype=np.uint8)
img4=np.ones((240,320), dtype=np.uint8)*255
img5=np.full((240,320),128, dtype=np.uint8)
img6=np.full((240,320,3),(0,255,255), dtype=np.uint8)

cv2.imshow('img1',img1)
cv2.imshow('img2',img2)
cv2.imshow('img3',img3)
cv2.imshow('img4',img4)
cv2.imshow('img5',img5)
cv2.imshow('img6',img6)

cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 영상 copy

# %%
import cv2

img1=cv2.imread('C:\deep\opencv\image\cup.jpg')

img2=img1 #img1 변경 -반영-> img2 변경
img3=img1.copy() #원본 img1 그대로

#img1[:,:]=(0,255,255) img1 변경 -반영-> img2 변경

cv2.imshow('img1',img1)
cv2.imshow('img2',img2)
cv2.imshow('img3',img3)

cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 마스크 연산 / ROI(관심영역)

# %% [markdown]
# 마스크 연산 지원하는 픽셀 값 복사 함수\
# cv2.copyTo(src, mask, dst=None) -> dst\
# src:입력영상\
# mask:0이 아닌 픽셀에 대해서만 복사 연산 수행\
# dst:출력영상

# %%
import cv2
import os
import sys
print(cv2.__version__)

src=cv2.imread('C:/deep/opencv/image/airplane.bmp', cv2.IMREAD_COLOR)
mask=cv2.imread('C:/deep/opencv/image/mask_plane.bmp', cv2.IMREAD_GRAYSCALE)
dst=cv2.imread('C:/deep/opencv/image/field.bmp', cv2.IMREAD_COLOR)

if src is None or mask is None or dst is None:
    print('image load failed')
    sys.exit()

cv2.copyTo(src,mask,dst)
#dst[mask>0]=src[mask>0]

cv2.imshow('src',src)
cv2.imshow('mask',mask)
cv2.imshow('dst',dst)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# 4.4.0

# %%
import numpy as np
import cv2

img=np.full((400,400,3), 255, np.uint8)
cv2.line(img, (50,50), (200,50),(0,0,255),5)
cv2.line(img, (50,60), (150,160),(0,0,128))

cv2.rectangle(img, (50,200),(150,100),(0,255,0),2)
cv2.rectangle(img, (70,220),(180,280),(0,128,0),-1)

cv2.circle(img, (300,100),30, (255,255,0),-1,cv2.LINE_AA)
cv2.circle(img, (300,100),60, (255,0,0),3,cv2.LINE_AA)

pts=np.array([[250,200],[300,200],[350,300],[250,300]])
cv2.polylines(img, [pts], True, (255,0,255),2)

text='Hello? OpenCV '+cv2.__version__
cv2.putText(img, text, (50,350),cv2.FONT_HERSHEY_SIMPLEX,0.8,
           (0,0,255),1, cv2.LINE_AA)
cv2.imshow('img',img)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 실습

# %%
latte1=cv2.imread('C:/deep/opencv/image/cup.jpg')

latte2=cv2.imread('C:/deep/opencv/image/cup.jpg', cv2.IMREAD_COLOR)

cv2.namedWindow('latte2',cv2.WINDOW_NORMAL)
cv2.line(latte2, (200,410), (280,410),180,5,cv2.LINE_AA)
cv2.circle(latte2, (250,100),30, (0,255,200),-1,cv2.LINE_AA)
cv2.rectangle(latte2, (150,100),(200,60),(0,255,0),4)
cv2.rectangle(latte2, (20,70),(140,30),(0,0,255),-1)


text='latte'
cv2.putText(latte2, text, (200,400),cv2.FONT_HERSHEY_DUPLEX,1.2,
           (255,255,255),4, cv2.LINE_AA)
cv2.imshow('latte1',latte1)
cv2.imshow('latte2',latte2)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
#답
latte2=cv2.imread('C:/deep/opencv/image/cup.jpg', cv2.IMREAD_COLOR)

cv2.namedWindow('latte2',cv2.WINDOW_NORMAL)
cv2.imshow('latte2', latte2)
latte2[20:50, 30:170]=(0,0,255)
cv2.rectangle(latte2, (180,40),(220,70),(0,255,0),5, cv2.LINE_AA)
cv2.circle(latte2, (250,85),25, (0,255,255),-1,cv2.LINE_AA)
cv2.line(latte2, (170,410), (320,410),(255,0,0),5,cv2.LINE_AA)
cv2.putText(latte2,'latte', (180,400),cv2.FONT_HERSHEY_DUPLEX,2,
           (255,255,255),4, cv2.LINE_AA)
cv2.namedWindow('latte',cv2.WINDOW_NORMAL)
cv2.imshow('latte',latte2)

cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 트랙바

# %% [markdown]
# cv2.createTrackbar(trackbarName,windowName, value, count, onChage) -> None\
# trackbarName:트랙바이름 \
# windowName:생성할 창 이름\
# value:위치초기값 \
# count:최대값(최솟값은0)\
# onChage:트랙바위치 변경마다 호출할 콜백함수이름

# %%
import numpy as np
import cv2

def on_level_chage(pos):
    value=pos*16
    if value>=255:
        value=255
        
    img[:]=value
    cv2.imshow('image',img)
    
img=np.zeros((480,640), np.uint8)
cv2.namedWindow('image')
cv2.createTrackbar('level','image',0,16,on_level_chage)

cv2.imshow('image',img)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 카메라 처리

# %% [markdown]
# 카메라 열기\
# cv2.VideoCapture() \
# cv2.VideoCapture.open(index, apiPreference=None) -> 성공 True/실패 False\
# -apiPreference:선호하는 카메라 처리방법 지정\
# 프레임 받아오기\
# cv2.VideoCapture.read(image=None) -> retval, image

# %%
import sys
import cv2

cap=cv2.VideoCapture(0)

if not cap.isOpened():
    print('Camera open failed')
    sys.exit()
    
print('Frame Width:',int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)))
print('Frame height:',int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)))
print('FPS:',int(cap.get(cv2.CAP_PROP_FPS)))
#cap.set(cv2.CAP_PROP_FRAME_WIDTH,320)
#cap.set(cv2.CAP_PROP_FRAME_HEIGHT,320)

while True:
    ret, frame=cap.read() #프레임 받아오는 함수/현재확인 불값
    if not ret:
        break
    
    #inversed=~frame #색상 반전
    #edge=cv2.Canny(frame,50,150)
    
    cv2.imshow('frame', frame)
    cv2.imshow('inversed', inversed)
    cv2.imshow('edge', edge)
    
    if cv2.waitKey(10)==27:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# Camera open failed
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\user\anaconda3\envs\cw\lib\site-packages\IPython\core\interactiveshell.py:3425: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# # 영상저장
# cv2.videoWriter()

# %%
import sys
import cv2

cap=cv2.VideoCapture(0)

if not cap.isOpened():
    print('Camera open failed')
    sys.exit()

w=round(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h=round(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps=cap.get(cv2.CAP_PROP_FPS)

fourcc=cv2.VideoWriter_fourcc(*'DIVX')
delay=round(1000/fps)

out=cv2.VideoWriter('C:/deep/opencv/output2.avi', fourcc, fps, (w,h))

if not out.isOpened():
    print('File open failed')
    cap.release()
    sys.exit()

while True:
    ret, frame=cap.read() #프레임 받아오는 함수/현재확인 불값
    if not ret:
        break
    
    inversed=~frame #색상 반전
    edge=cv2.Canny(frame,50,150)
    edge_color=cv2.cvtColor(edge, cv2.COLOR_GRAYSCALE)
    cv2.imshow('frame', frame)
    cv2.imshow('inversed', inversed)
    cv2.imshow('edge', edge)
    cv2.imshow('edge_COLOR', edge_color)

    if cv2.waitKey(10)==27:
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 키보드

# %%
import sys
import cv2

img=cv2.imread('C:/deep/opencv/image/cup.jpg', cv2.IMREAD_GRAYSCALE)

if img is None:
    print('image load failed')
    sys.exit()
    
cv2.namedWindow('image')
cv2.imshow('image',img)

while True:
    keycode=cv2.waitKey()
    if keycode==ord('i') or keycode==ord('l'):
        img=~img
        cv2.imshow('image',img)
    elif keycode==27:
        break
cv2.destroyAllWindows()

# %% [markdown]
# # 마우스
# cv2.setMouseCallback
# cv2.onMouse

# %%
import sys
import numpy as np
import cv2

oldx=oldy=-1

def on_mouse(event, x, y, flags, param):
    global oldx, oldy
    if event==cv2.EVENT_LBUTTONDOWN:
        oldx, oldy=x,y
        print("EVENT_LBUTTONDOWN: %d, %d" %(x,y))
    elif event==cv2.EVENT_LBUTTONUP:
        print("EVENT_LBUTTONUP: %d, %d" %(x,y))
    elif event==cv2.EVENT_MOUSEMOVE:
        print("EVENT_MOUSEMOVE: {}, {}".format(x,y))

img=np.ones((480,640,3), dtype=np.uint8)*255

cv2.namedWindow('image')
cv2.setMouseCallback('image',on_mouse,img)

cv2.imshow('image',img)
cv2.waitKey()

cv2.destroyAllWindows()
# Out:
# EVENT_MOUSEMOVE: 601, 478
# EVENT_MOUSEMOVE: 601, 478
# EVENT_MOUSEMOVE: 579, 446
# EVENT_MOUSEMOVE: 562, 414
# EVENT_MOUSEMOVE: 546, 385
# EVENT_MOUSEMOVE: 531, 359
# EVENT_MOUSEMOVE: 517, 335
# EVENT_MOUSEMOVE: 509, 317
# EVENT_MOUSEMOVE: 502, 300
# EVENT_MOUSEMOVE: 498, 290
# EVENT_MOUSEMOVE: 494, 280
# EVENT_MOUSEMOVE: 491, 273
# EVENT_MOUSEMOVE: 491, 273
# EVENT_MOUSEMOVE: 488, 267
# EVENT_MOUSEMOVE: 488, 267
# EVENT_MOUSEMOVE: 488, 264
# EVENT_MOUSEMOVE: 488, 263
# EVENT_MOUSEMOVE: 488, 263
# EVENT_MOUSEMOVE: 489, 263
# EVENT_MOUSEMOVE: 493, 264
# EVENT_MOUSEMOVE: 495, 265
# EVENT_MOUSEMOVE: 496, 267
# EVENT_MOUSEMOVE: 497, 267
# EVENT_MOUSEMOVE: 497, 268
# EVENT_MOUSEMOVE: 497, 269
# EVENT_MOUSEMOVE: 497, 269
# EVENT_MOUSEMOVE: 497, 271
# EVENT_MOUSEMOVE: 494, 273
# EVENT_MOUSEMOVE: 488, 273
# EVENT_MOUSEMOVE: 480, 273
# EVENT_MOUSEMOVE: 472, 273
# EVENT_MOUSEMOVE: 462, 273
# EVENT_MOUSEMOVE: 454, 271
# EVENT_MOUSEMOVE: 444, 268
# EVENT_MOUSEMOVE: 433, 264
# ...

# %%
#빈화면에 마우스로 그림그리는 함수
import sys
import numpy as np
import cv2

oldx=oldy=-1

def on_mouse(event, x, y, flags, param):
    global oldx, oldy
    if event==cv2.EVENT_LBUTTONDOWN:
        oldx, oldy=x,y
        print("EVENT_LBUTTONDOWN: %d, %d" %(x,y))
    elif event==cv2.EVENT_LBUTTONUP:
        print("EVENT_LBUTTONUP: %d, %d" %(x,y))
    elif event==cv2.EVENT_MOUSEMOVE:
        if flags&cv2.EVENT_FLAG_LBUTTON:
            cv2.line(img, (oldx, oldy), (x,y),(0,0,255),4,cv2.LINE_AA)
            oldx, oldy=x,y

img=np.ones((480,640,3), dtype=np.uint8)*255

cv2.namedWindow('image')
cv2.setMouseCallback('image',on_mouse,img)

cv2.imshow('image',img)
cv2.waitKey()

cv2.destroyAllWindows()
# Out:
# EVENT_LBUTTONDOWN: 72, 175
# EVENT_LBUTTONUP: 434, 236
# EVENT_LBUTTONDOWN: 267, 178
# EVENT_LBUTTONUP: 267, 178
# EVENT_LBUTTONDOWN: 351, 199
# EVENT_LBUTTONUP: 436, 196
# EVENT_LBUTTONDOWN: 390, 246
# EVENT_LBUTTONUP: 390, 246
# EVENT_LBUTTONDOWN: 390, 246
# EVENT_LBUTTONUP: 390, 246
# EVENT_LBUTTONDOWN: 6, 5
# EVENT_LBUTTONUP: 6, 5
# EVENT_LBUTTONDOWN: 630, 472
# EVENT_LBUTTONUP: 630, 472
# EVENT_LBUTTONDOWN: 290, 259
# EVENT_LBUTTONUP: 290, 259
# EVENT_LBUTTONDOWN: 290, 259
# EVENT_LBUTTONUP: 290, 259
# EVENT_LBUTTONDOWN: 230, 275
# EVENT_LBUTTONUP: 476, 131
# EVENT_LBUTTONDOWN: 187, 199
# EVENT_LBUTTONUP: 456, 93
