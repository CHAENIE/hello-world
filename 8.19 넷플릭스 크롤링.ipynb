# %%
import time
import pandas as pd
from selenium import webdriver as wd
from tqdm.notebook import tqdm
import re

driver=wd.Chrome("C:/chromedriver")
url='https://play.google.com/store/apps/details?id=com.netflix.mediaclient&hl=en'

driver.get(url)
time.sleep(1)

driver.find_element_by_css_selector("#fcxH9b > div.WpDbMd > c-wiz.zQTmif.SSPGKf.I3xX3c.drrice > div > div.ZfcPIb > div > div > main > div > div.W4P4ne > div.XnFhVd > div > span > span").click()
time.sleep(5)

review=[]

for i in range(1, 100):
    #full_review=driver.find_elements_by_css_selector("#fcxH9b > div.WpDbMd > c-wiz:nth-child(7) > div > div.ZfcPIb > div > div > main > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child({0}) > div > div.d15Mdf.bAhLNe > div.UD7Dzf > span:nth-child(1) > div > button").click()
    reviews=driver.find_elements_by_css_selector("#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div > main > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child("+str(i)+") > div > div.d15Mdf.bAhLNe > div.UD7Dzf")
    print(len(reviews))
    print(reviews)
    
    for r in reviews:
        review.append(r.text)
        print("hi")
        print(r.text)

print(review)

#result_file_path='Netflix_review_' +'.txt'
#result_file=open(result_file_path,'w',encoding='utf-8')

#for reviews in review:
    #print(reviews, file=result_file)
    
#result_file.close()

file=open('Netflix_review.txt','w',encoding='utf-8')
for reviews in review:
    file.write(reviews + '\n')
file.close()
# Out:
# 1
# [<selenium.webdriver.remote.webelement.WebElement (session="6f276915c647dc5b17f83796b92281f9", element="49932072-868b-452a-969e-d2e7d319518d")>]
# hi
# It's great, but why I didn't give it 5 star's is because that the TV show's take a long time for a new season to come, and cartoon / animation TV shows like star wars rebels or clone wars and like DreamWorks dragon (Not Race to the edge) is not available. Even though it's an old series. And there ar...
# Full Review
# 1
# [<selenium.webdriver.remote.webelement.WebElement (session="6f276915c647dc5b17f83796b92281f9", element="d9f953a5-8fa8-46b3-bae6-89a04900cec7")>]
# hi
# I am fairly new to the Netflix app, and first impressions are good, but it needs a little tweaking. Firstly you should ALWAYS be able to tell who is signed in just by looking, so it should have the persons name showing sonewhere on the screen. Next, you should be able to do the same on the app as on...
# Full Review
# 1
# ...
